# %% [markdown]
# <a href="https://colab.research.google.com/github/biapeabody/Projeto_Final_Dados_03_10_ENEM_RR/blob/main/2_Notebooks_Colab/Enem2024_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Bibliotecas & Conexão com o Google Drive**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Base de Dados - ENEM 2024**

# %%
caminho = '/content/drive/MyDrive/Projeto Final - DADOS_3_10/1. Bases de Dados/Dados_2024/RESULTADOS_2024.csv'

df = pd.read_csv(caminho, sep=';', encoding='latin1')

df.head()
# Out:
#    NU_SEQUENCIAL  NU_ANO   CO_ESCOLA  CO_MUNICIPIO_ESC  \
# 0         206403    2024  23052929.0         2301406.0
# 1        3604651    2024  42103770.0         4218004.0
# 2        1461268    2024         NaN               NaN
# 3        4301058    2024         NaN               NaN
# 4        3148322    2024  21150354.0         2100436.0
#
#           NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  \
# 0                  Aratuba       23.0        CE                     2.0
# 1                  Tijucas       42.0        SC                     4.0
# 2                      NaN        NaN       NaN                     NaN
# 3                      NaN        NaN       NaN                     NaN
# 4  Alto Alegre do Maranhão       21.0        MA                     2.0
#
#    TP_LOCALIZACAO_ESC  TP_SIT_FUNC_ESC  ...  \
# 0                 1.0              1.0  ...
# 1                 1.0              1.0  ...
# 2                 NaN              NaN  ...
# 3                 NaN              NaN  ...
# 4                 1.0              1.0  ...
#
#                                   TX_GABARITO_CH  \
# 0  CECEBEBCDBADDEBBABCDCAECEDADBAEABEADCEDADACBC
# 1  DADABCDCECEDEBBBEBCDBADACBCADCEBEADBAECAECEDA
# 2  CAEDBADBEBCCEDADBAEACBCADCEDEBBEBACECEABCDDAD
# 3  ACBCADCEDBAECEDADBADBEBCDADABCDEABCAEDEBBCECE
# 4                                            NaN
#
#                                       TX_GABARITO_LC  \
# 0  CAAAECDDDAECBECEDDCBDEDDCECBDCBCEADBBDBDDCBEDA...
# 1  AACEADDDACDADECBBDBEEBDDECCBEDDCADBBDEBCEBDCEC...
# 2  EAAACDDCDADDCBDEECEECBDCDADEEBCBEBADBCEBDBDDDD...
# 3  AACEADACDDCBEDADEEBDDBDBBCEECBDCBADDDCBDEDDCEC...
# 4                                                NaN
#
#                                   TX_GABARITO_MT TP_STATUS_REDACAO  \
# 0  CECEBEDADCAADECDBBCEBDCCCACABBABBADDDCEADBBCE               1.0
# 1  DBCECEACADABBECBEDADCCDCCABBBCECEBCEADABBADDD               1.0
# 2  ABBABBADDDBBCECEADCEBCCCDBADCBEDAECADACDBCECE               1.0
# 3  CEBCEADBBCEADDDABBABBCCDCCECEDBACADECABEDADCB               1.0
# 4                                            NaN               NaN
#
#    NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  \
# 0           80.0           60.0           60.0           80.0           20.0
# 1          160.0          200.0          200.0          180.0          180.0
# 2          120.0          120.0           40.0          120.0           80.0
# 3          140.0          200.0          160.0          160.0           80.0
# 4            NaN            NaN            NaN            NaN            NaN
#
#    NU_NOTA_REDACAO
# 0            300.0
# 1            920.0
# 2            480.0
# 3            740.0
# 4              NaN
#
# [5 rows x 42 columns]

# %%
df.shape
# (linhas, colunas)
# Out:
# (4332944, 42)

# %%
df.info()
# tipos de dados e se há valores nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4332944 entries, 0 to 4332943
# Data columns (total 42 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_SEQUENCIAL           int64
#  1   NU_ANO                  int64
#  2   CO_ESCOLA               float64
#  3   CO_MUNICIPIO_ESC        float64
#  4   NO_MUNICIPIO_ESC        object
#  5   CO_UF_ESC               float64
#  6   SG_UF_ESC               object
#  7   TP_DEPENDENCIA_ADM_ESC  float64
#  8   TP_LOCALIZACAO_ESC      float64
#  9   TP_SIT_FUNC_ESC         float64
#  10  CO_MUNICIPIO_PROVA      int64
#  11  NO_MUNICIPIO_PROVA      object
#  12  CO_UF_PROVA             int64
#  13  SG_UF_PROVA             object
#  14  TP_PRESENCA_CN          int64
#  15  TP_PRESENCA_CH          int64
#  16  TP_PRESENCA_LC          int64
#  17  TP_PRESENCA_MT          int64
#  18  CO_PROVA_CN             float64
#  19  CO_PROVA_CH             float64
#  20  CO_PROVA_LC             float64
#  21  CO_PROVA_MT             float64
#  22  NU_NOTA_CN              float64
#  23  NU_NOTA_CH              float64
#  24  NU_NOTA_LC              float64
#  25  NU_NOTA_MT              float64
#  26  TX_RESPOSTAS_CN         object
#  27  TX_RESPOSTAS_CH         object
#  28  TX_RESPOSTAS_LC         object
#  29  TX_RESPOSTAS_MT         object
#  30  TP_LINGUA               int64
#  31  TX_GABARITO_CN          object
#  32  TX_GABARITO_CH          object
#  33  TX_GABARITO_LC          object
#  34  TX_GABARITO_MT          object
#  35  TP_STATUS_REDACAO       float64
#  36  NU_NOTA_COMP1           float64
#  37  NU_NOTA_COMP2           float64
#  38  NU_NOTA_COMP3           float64
#  39  NU_NOTA_COMP4           float64
#  40  NU_NOTA_COMP5           float64
#  41  NU_NOTA_REDACAO         float64
# dtypes: float64(21), int64(9), object(12)
# memory usage: 1.4+ GB

# %%
list(df.columns)
# listando as colunas - de forma organizada
# Out:
# ['NU_SEQUENCIAL',
#  'NU_ANO',
#  'CO_ESCOLA',
#  'CO_MUNICIPIO_ESC',
#  'NO_MUNICIPIO_ESC',
#  'CO_UF_ESC',
#  'SG_UF_ESC',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'TP_LOCALIZACAO_ESC',
#  'TP_SIT_FUNC_ESC',
#  'CO_MUNICIPIO_PROVA',
#  'NO_MUNICIPIO_PROVA',
#  'CO_UF_PROVA',
#  'SG_UF_PROVA',
#  'TP_PRESENCA_CN',
#  'TP_PRESENCA_CH',
#  'TP_PRESENCA_LC',
#  'TP_PRESENCA_MT',
#  'CO_PROVA_CN',
#  'CO_PROVA_CH',
#  'CO_PROVA_LC',
#  'CO_PROVA_MT',
#  'NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_LC',
#  'NU_NOTA_MT',
#  'TX_RESPOSTAS_CN',
#  'TX_RESPOSTAS_CH',
#  'TX_RESPOSTAS_LC',
#  'TX_RESPOSTAS_MT',
#  'TP_LINGUA',
#  'TX_GABARITO_CN',
#  'TX_GABARITO_CH',
#  'TX_GABARITO_LC',
#  'TX_GABARITO_MT',
#  'TP_STATUS_REDACAO',
#  'NU_NOTA_COMP1',
#  'NU_NOTA_COMP2',
#  'NU_NOTA_COMP3',
#  'NU_NOTA_COMP4',
#  'NU_NOTA_COMP5',
#  'NU_NOTA_REDACAO']

# %%
# Filtrar apenas os registros de Roraima (SG_UF_PROVA == 'RR')
df_limpo = df[df['SG_UF_PROVA'] == 'RR']

# %%
df_limpo.shape
# (linhas, colunas)
# Out:
# (12695, 42)

# %%
df_limpo['SG_UF_PROVA'].value_counts()
# Out:
# SG_UF_PROVA
# RR    12695
# Name: count, dtype: int64

# %%
# lista das colunas que vão ficar, as demais vão ser dropadas (mesmas colunas de 2024)
# em 2024 fiz dic de colunas para remover, aqui fiz o inverso (mais fácil) para não errar

colunas_desejadas = [
    'NU_ANO',
    #'TP_ESCOLA', não existe em nenhuma das 3 bases de 2024
    'TP_DEPENDENCIA_ADM_ESC',
    'TP_LOCALIZACAO_ESC',
    'NO_MUNICIPIO_PROVA',
    'SG_UF_PROVA'
]

df_limpo = df_limpo[colunas_desejadas]

# %%
df_limpo.shape
# (linhas, colunas)
# Out:
# (12695, 5)

# %%
list(df_limpo.columns)
# listando as colunas - de forma organizada
# Out:
# ['NU_ANO',
#  'TP_DEPENDENCIA_ADM_ESC',
#  'TP_LOCALIZACAO_ESC',
#  'NO_MUNICIPIO_PROVA',
#  'SG_UF_PROVA']

# %% [markdown]
# ## **Base de Dados - Transformação**

# %%
df_limpo.head()
# Out:
#       NU_ANO  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC NO_MUNICIPIO_PROVA  \
# 86      2024                     NaN                 NaN             Bonfim
# 1611    2024                     NaN                 NaN          Boa Vista
# 1846    2024                     NaN                 NaN          Boa Vista
# 1897    2024                     2.0                 1.0          Boa Vista
# 2122    2024                     NaN                 NaN          Boa Vista
#
#      SG_UF_PROVA
# 86            RR
# 1611          RR
# 1846          RR
# 1897          RR
# 2122          RR

# %%
mapeamento_dependencia = {
    1: 'Federal',
    2: 'Estadual',
    3: 'Municipal',
    4: 'Privada'
}

df_limpo['TP_DEPENDENCIA_ADM_ESC'] = df_limpo['TP_DEPENDENCIA_ADM_ESC'].map(mapeamento_dependencia)
# Out:
# /tmp/ipython-input-2150587841.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpo['TP_DEPENDENCIA_ADM_ESC'] = df_limpo['TP_DEPENDENCIA_ADM_ESC'].map(mapeamento_dependencia)

# %%
# distribuição de cada coluna
print(df_limpo['TP_DEPENDENCIA_ADM_ESC'].value_counts())
# Out:
# TP_DEPENDENCIA_ADM_ESC
# Estadual    4394
# Privada      409
# Federal      274
# Name: count, dtype: int64

# %%
mapa_localizacao = {
    1: 'Urbana',
    2: 'Rural'
}

df_limpo['TP_LOCALIZACAO_ESC'] = df_limpo['TP_LOCALIZACAO_ESC'].map(mapa_localizacao)
# Out:
# /tmp/ipython-input-774052477.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpo['TP_LOCALIZACAO_ESC'] = df_limpo['TP_LOCALIZACAO_ESC'].map(mapa_localizacao)

# %%
print(df_limpo['TP_LOCALIZACAO_ESC'].value_counts())
# Out:
# TP_LOCALIZACAO_ESC
# Urbana    4586
# Rural      491
# Name: count, dtype: int64

# %%
df_limpo.head(20)
# Out:
#       NU_ANO TP_DEPENDENCIA_ADM_ESC TP_LOCALIZACAO_ESC NO_MUNICIPIO_PROVA  \
# 86      2024                    NaN                NaN             Bonfim
# 1611    2024                    NaN                NaN          Boa Vista
# 1846    2024                    NaN                NaN          Boa Vista
# 1897    2024               Estadual             Urbana          Boa Vista
# 2122    2024                    NaN                NaN          Boa Vista
# 2247    2024                    NaN                NaN          Boa Vista
# 3600    2024               Estadual             Urbana          Boa Vista
# 3678    2024               Estadual             Urbana          Boa Vista
# 4509    2024               Estadual             Urbana          Boa Vista
# 4771    2024                    NaN                NaN          Boa Vista
# 5188    2024                    NaN                NaN          Boa Vista
# 5327    2024               Estadual             Urbana          Boa Vista
# 5341    2024               Estadual             Urbana          Boa Vista
# 5395    2024                    NaN                NaN          Boa Vista
# 5524    2024               Estadual             Urbana            Mucajaí
# 5626    2024                    NaN                NaN          Boa Vista
# 6001    2024                    NaN                NaN          Boa Vista
# 6310    2024                    NaN                NaN            Mucajaí
# 7174    2024               Estadual             Urbana          Boa Vista
# 7429    2024                    NaN                NaN          Boa Vista
#
#      SG_UF_PROVA
# 86            RR
# 1611          RR
# 1846          RR
# 1897          RR
# 2122          RR
# 2247          RR
# 3600          RR
# 3678          RR
# 4509          RR
# 4771          RR
# 5188          RR
# 5327          RR
# 5341          RR
# 5395          RR
# 5524          RR
# 5626          RR
# 6001          RR
# 6310          RR
# 7174          RR
# 7429          RR

# %%
df_limpo.shape
# (linhas, colunas)
# Out:
# (12695, 5)

# %%
# Dicionário de renomeação
novos_nomes = {
    'NU_ANO': 'ano',
    'NO_MUNICIPIO_PROVA': 'municipio_prova',
    'SG_UF_PROVA': 'uf_prova',
    'TP_DEPENDENCIA_ADM_ESC': 'dependencia_adm_escola',
    'TP_LOCALIZACAO_ESC': 'localizacao_escola'
}

# nova variavel para novo dataset
# df → df_limpo → df_limpo_rr
df_limpo_rr = df_limpo.rename(columns=novos_nomes)

# ver as novas colunas
df_limpo_rr.columns
# Out:
# Index(['ano', 'dependencia_adm_escola', 'localizacao_escola',
#        'municipio_prova', 'uf_prova'],
#       dtype='object')

# %%
df_limpo_rr.head()
# Out:
#        ano dependencia_adm_escola localizacao_escola municipio_prova uf_prova
# 86    2024                    NaN                NaN          Bonfim       RR
# 1611  2024                    NaN                NaN       Boa Vista       RR
# 1846  2024                    NaN                NaN       Boa Vista       RR
# 1897  2024               Estadual             Urbana       Boa Vista       RR
# 2122  2024                    NaN                NaN       Boa Vista       RR

# %%
pasta_destino = '/content/drive/MyDrive/Projeto Final - DADOS_3_10/3. Bases de Dados Limpas'

# nome do arquivo .csv lá na pasta destino
arquivo_destino = pasta_destino + '/enem2024_2_rr_limpo.csv'

# df_limpo_rr vai ser salvo em .cvs
df_limpo_rr.to_csv(arquivo_destino, index=False, sep=';', encoding='utf-8')

print(f"Arquivo salvo em: {arquivo_destino}")
# Out:
# Arquivo salvo em: /content/drive/MyDrive/Projeto Final - DADOS_3_10/3. Bases de Dados Limpas/enem2024_2_rr_limpo.csv
